# %% [markdown]
# ### Mathamatical Operations Without using loops

# %%
import numpy as np

# %%
arr = np.array([10,20,30])

print(f'Added 5 In All Values: {arr + 5}')
print(f'Multiply all values by 2 : {arr * 2}')
print(f'All Values Squre: {arr ** 2}')
# Out:
# Added 5 In All Values: [15 25 35]
# Multiply all values by 2 : [20 40 60]
# All Values Squre: [100 400 900]

# %%
new_arr = arr - 2

# %%
print(new_arr)
# Out:
# [ 8 18 28]

# %%
arr
# Out:
# array([10, 20, 30])

# %%
new_arr
# Out:
# array([ 8, 18, 28])
