# %% [markdown]
# # Append
# - **Used to add element in array at the end of array**
# ### Syntax:
# - **.append(Array_Name [Element / Value])**

# %%
import numpy as np

# %%
# Array
arr = np.array([1,2,3,4,5])

new_arr = np.append(arr,[10,20])
print(new_arr)
# Out:
# [ 1  2  3  4  5 10 20]
